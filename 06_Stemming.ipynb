# %%
words1 = 'working', 'work', 'worked', 'workable'
words2 = 'bigger', 'biggest', 'big'
words3 = 'consulting', 'consultation', 'consulted', 'consultative'
words4 = 'player', 'played', 'players', 'playing', 'plays'

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
for word in words1:
    print(word, '->', ps.stem(word))
# Out:
# working -> work
# work -> work
# worked -> work
# workable -> workabl

# %%
for word in words3:
    print(word, '->', ps.stem(word))
# Out:
# consulting -> consult
# consultation -> consult
# consulted -> consult
# consultative -> consult

# %%
for word in words4:
    print(word, '->', ps.stem(word))
# Out:
# player -> player
# played -> play
# players -> player
# playing -> play
# plays -> play

# %%
from nltk.stem import LancasterStemmer

# %%
ls = LancasterStemmer()

# %%
for word in words1:
    print(word, '->', ls.stem(word))
# Out:
# working -> work
# work -> work
# worked -> work
# workable -> work

# %%
for word in words2:
    print(word, '->', ls.stem(word))
# Out:
# bigger -> big
# biggest -> biggest
# big -> big

# %%
for word in words3:
    print(word, '->', ls.stem(word))
# Out:
# consulting -> consult
# consultation -> consult
# consulted -> consult
# consultative -> consult

# %%
for word in words4:
    print(word, '->', ls.stem(word))
# Out:
# player -> play
# played -> play
# players -> play
# playing -> play
# plays -> play

# %%
sent = 'Hello friends! How are you? I Like Python Programming'

# %%
# remove stopwords, punctucations and suffixes and print the list of words

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
words = word_tokenize(sent)
swords = stopwords.words('english')

# %%
import string
clean_words = []
for word in words:
    if word.lower() not in swords and word not in string.punctuation:
        clean_words.append(ps.stem(word))

print(clean_words)
# Out:
# ['hello', 'friend', 'like', 'python', 'program']

# %%
sent2 = '''Hello friends! How are you? My friend likes to program in Python Programming language.'''

# %%
words2 = word_tokenize(sent2)

# %%
import string
clean_words2 = []
for word in words2:
    if word.lower() not in swords and word not in string.punctuation:
        clean_words2.append(ps.stem(word))

clean_words2
# Out:
# ['hello',
#  'friend',
#  'friend',
#  'like',
#  'program',
#  'python',
#  'program',
#  'languag']
