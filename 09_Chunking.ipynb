# %%
import subprocess, sys
subprocess.check_call([sys.executable, "-m", "pip", "install", "svgling"])
# Out:
# 0

# %%
from nltk.tokenize import word_tokenize
from nltk import pos_tag, RegexpParser
from nltk.parse import CoreNLPParser

# %%
# Create the chunk grammer for regular expression
grammer = "NP:{<DT><JJ><NN>}"

# %%
sent = 'It was a beautiful game by him. An amazing play was witnessed.'

# %%
parser = RegexpParser(grammer)

# %%
tree = parser.parse(pos_tag(word_tokenize(sent)))

# %%
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('beautiful', 'JJ'), ('game', 'NN')]), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('was', 'VBD'), ('witnessed', 'VBN'), ('.', '.')])

# %%
# <DT>? : 0 or more Determiner
# <JJ>* : 0 or more Adj
# <NN>+ : one or more Noun
grammer = "NP:{<DT>?<JJ>*<NN>+}"
sent = 'It was a beautiful fine game by him. An amazing play was witnessed.'

# %%
parser = RegexpParser(grammer)

# %%
tree = parser.parse(pos_tag(word_tokenize(sent)))

# %%
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('beautiful', 'JJ'), ('fine', 'JJ'), ('game', 'NN')]), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('was', 'VBD'), ('witnessed', 'VBN'), ('.', '.')])

# %% [markdown]
# # NER Chunking

# %%
import nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('maxent_ne_chunker')   # download this too just in case
nltk.download('words')               # also required by ne_chunk
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\PGCP-AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker_tab.zip.
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data] Downloading package words to C:\Users\PGCP-
# [nltk_data]     AI\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
from nltk import ne_chunk

# %%
sent = 'Mark Zukerberg is CEO of Meta at California.'
tree = ne_chunk(pos_tag(word_tokenize(sent)))

# %%
tree
# Out:
# Tree('S', [Tree('PERSON', [('Mark', 'NNP')]), Tree('PERSON', [('Zukerberg', 'NNP')]), ('is', 'VBZ'), ('CEO', 'NNP'), ('of', 'IN'), Tree('ORGANIZATION', [('Meta', 'NNP')]), ('at', 'IN'), Tree('GPE', [('California', 'NNP')]), ('.', '.')])

# %%
tree.leaves()
# Out:
# [('Mark', 'NNP'),
#  ('Zukerberg', 'NNP'),
#  ('is', 'VBZ'),
#  ('CEO', 'NNP'),
#  ('of', 'IN'),
#  ('Meta', 'NNP'),
#  ('at', 'IN'),
#  ('California', 'NNP'),
#  ('.', '.')]
