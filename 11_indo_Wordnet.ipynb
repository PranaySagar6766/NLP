# %%
# Read the file
iwn_path = r"C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages\pyiwn\iwn.py"

with open(iwn_path, 'r', encoding='utf-8') as f:
    content = f.read()

# Apply the fix
fixed = content.replace(
    'f = open(filename)',
    "f = open(filename, encoding='utf-8')"
)

# Write it back
with open(iwn_path, 'w', encoding='utf-8') as f:
    f.write(fixed)

print("✅ Patch applied successfully!")
# Out:
# ✅ Patch applied successfully!

# %%
pip install pyiwn
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pyiwn in C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\site-packages (0.0.5)
# Requirement already satisfied: pandas in C:\ProgramData\anaconda3\Lib\site-packages (from pyiwn) (2.2.2)
# Requirement already satisfied: requests in C:\ProgramData\anaconda3\Lib\site-packages (from pyiwn) (2.32.3)
# Requirement already satisfied: numpy>=1.26.0 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas->pyiwn) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas->pyiwn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas->pyiwn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in C:\ProgramData\anaconda3\Lib\site-packages (from pandas->pyiwn) (2023.3)
# Requirement already satisfied: six>=1.5 in C:\ProgramData\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas->pyiwn) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->pyiwn) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->pyiwn) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->pyiwn) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->pyiwn) (2026.1.4)
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyiwn
# Out:
# 2026-05-30:12:31:18,170 INFO     [utils.py:148] Note: NumExpr detected 16 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# 2026-05-30:12:31:18,172 INFO     [utils.py:160] NumExpr defaulting to 8 threads.

# %%
iwn = pyiwn.IndoWordNet(lang=pyiwn.Language.MARATHI)
# Out:
# 2026-05-30:12:31:18,780 INFO     [iwn.py:43] Loading marathi language synsets...

# %%
word = iwn.synsets('आंबा')

# %%
word
# Out:
# [Synset('आंबा.noun.3462'), Synset('आंबा.noun.3463')]

# %%
hyponyms = iwn.synset_relation(word[0],pyiwn.SynsetRelations.HYPONYMY)

# %%
for h in hyponyms:
    print(h.lemma_names()[0])
# Out:
# बाळांबा
# चौसा
# सिंदूरिया आंबा
# सेसिल
# सैगॉन
# डेविस हॅडन
# बिजवड आंबा
# कैरी
# राजापुरी
# तोतापुरी
# लंगडा
# दशहरी
# हापूस
# पायरी
# नीलम
# केशर
# सफेदा
# रुमानी
# गोवाबंदर
# बेनिशान
# जरदाळू
# सुंदरी
# कॅरी
# सिंगापुरी आंबा
# माया
# शेंदरी
# बदामी
# बैंगनपल्ली
# बंगलोरा
# गुलाबखास
# खजरी
# फजली
# वनराज आंबा
