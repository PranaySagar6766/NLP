# %%
pip install language_tool_python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting language_tool_python
#   Downloading language_tool_python-3.4.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests in C:\ProgramData\anaconda3\Lib\site-packages (from language_tool_python) (2.32.3)
# Requirement already satisfied: tqdm in C:\ProgramData\anaconda3\Lib\site-packages (from language_tool_python) (4.66.5)
# Requirement already satisfied: packaging in C:\ProgramData\anaconda3\Lib\site-packages (from language_tool_python) (24.1)
# Requirement already satisfied: psutil in C:\ProgramData\anaconda3\Lib\site-packages (from language_tool_python) (5.9.0)
# Requirement already satisfied: toml in C:\ProgramData\anaconda3\Lib\site-packages (from language_tool_python) (0.10.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->language_tool_python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->language_tool_python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->language_tool_python) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\ProgramData\anaconda3\Lib\site-packages (from requests->language_tool_python) (2026.1.4)
# Requirement already satisfied: colorama in C:\ProgramData\anaconda3\Lib\site-packages (from tqdm->language_tool_python) (0.4.6)
# Downloading language_tool_python-3.4.0-py3-none-any.whl (63 kB)
# Installing collected packages: language_tool_python
# Successfully installed language_tool_python-3.4.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script language_tool_python.exe is installed in 'C:\Users\PGCP-AI\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 26.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import language_tool_python

# %%
mytool = language_tool_python.LanguageTool('en-US', language_tool_download_version='5.9')
# Out:
# Downloading LanguageTool 5.9: 100%|██████████| 231M/231M [00:06<00:00, 38.1MB/s]

# %%
my_text = "He have collected a documents. When I is there"
matches = mytool.check(my_text)
len(matches)
# Out:
# 3

# %%
for m in matches:
    print(m)
# Out:
# Offset 3, length 4, Rule ID: HE_VERB_AGR
# Message: The pronoun ‘He’ is usually used with a third-person or a past tense verb.
# Suggestion: has; had
# He have collected a documents. When I is there
#    ^^^^
# Offset 18, length 11, Rule ID: A_NNS
# Message: The plural noun “documents” cannot be used with the article “a”. Did you mean “a document” or “documents”?
# Suggestion: a document; documents
# He have collected a documents. When I is there
#                   ^^^^^^^^^^^
# Offset 38, length 2, Rule ID: PERS_PRONOUN_AGREEMENT
# Message: Did you mean “am” or “will be”?
# Suggestion: am; will be
# He have collected a documents. When I is there
#                                       ^^

# %%
mytool.correct(my_text)
# Out:
# 'He has collected a document. When I am there'
