# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(-5, 5, 0.25)

# %%
x
# Out:
# array([-5.  , -4.75, -4.5 , -4.25, -4.  , -3.75, -3.5 , -3.25, -3.  ,
#        -2.75, -2.5 , -2.25, -2.  , -1.75, -1.5 , -1.25, -1.  , -0.75,
#        -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,  1.  ,  1.25,  1.5 ,
#         1.75,  2.  ,  2.25,  2.5 ,  2.75,  3.  ,  3.25,  3.5 ,  3.75,
#         4.  ,  4.25,  4.5 ,  4.75])

# %%
y = x*3.76 + 10.29

# %%
y
# Out:
# array([-8.51, -7.57, -6.63, -5.69, -4.75, -3.81, -2.87, -1.93, -0.99,
#        -0.05,  0.89,  1.83,  2.77,  3.71,  4.65,  5.59,  6.53,  7.47,
#         8.41,  9.35, 10.29, 11.23, 12.17, 13.11, 14.05, 14.99, 15.93,
#        16.87, 17.81, 18.75, 19.69, 20.63, 21.57, 22.51, 23.45, 24.39,
#        25.33, 26.27, 27.21, 28.15])

# %%
plt.plot(x, y)

# %%
x = np.arange(0, 5, 0.25)
y = x**3.76 + 10.29

# %%
plt.plot(x,y)

# %%
y = (x**3)*3.76 + 10.29
plt.plot(x,y)

# %%
plt.plot(x, np.log(x))
# Out:
# C:\Users\PGCP-AI\AppData\Local\Temp\ipykernel_5436\2742365056.py:1: RuntimeWarning: divide by zero encountered in log
#   plt.plot(x, np.log(x))

# %%
x = np.arange(-5, 5, 0.25)
y = 1/(1+np.exp(-x))
plt.plot(x, y)
